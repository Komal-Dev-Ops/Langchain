# %%
import langchain
import numpy
print(langchain.__version__)
print(numpy.__version__)

# %%
import os

# %%
from dotenv import load_dotenv

# %%
load_dotenv()

# %%
api_key=os.getenv("OPENAI_API_KEY")

# %%
if api_key:
    print("API_KEY:",api_key[0:10])
else:
    print("API key not loaded?")
